# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
worlddata = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
worlddata.plot()

# %%
cwd = os.getcwd()
print(os.listdir(cwd))
marriagedatapath = cwd + '/indicator_age_of_marriage.xlsx'
print(marriagedatapath)
data = pd.read_excel(marriagedatapath, sheet_name=None)
year_2005 = data['Data'].iloc[:,-1]
# Out:
# ['Untitled.ipynb', 'indicator_age_of_marriage.xlsx', 'state_class.py', 'untitled', '.ipynb_checkpoints', 'geopandas_try.py', 'readme.md', 'geopandas_try.ipynb', 'gym_dc', 'RL_agent.py', 'git_cheatsheet.txt']
# /home/tf74693/Desktop/DC_RL/indicator_age_of_marriage.xlsx

# %%
# geocode all values 
locations = pd.Series(year_2005.index)
# uses the google geocoding API to get locations of names in file
geocoded_locations = gpd.tools.geocode(locations, provider='google')
# Out:
# ---------------------------------------------------------------------------
# GeocoderQuotaExceeded                     Traceback (most recent call last)
# <ipython-input-4-93ad79be6942> in <module>()
#       2 locations = pd.Series(year_2005.index)
#       3 # uses the google geocoding API to get locations of names in file
# ----> 4 geocoded_locations = gpd.tools.geocode(locations, provider='google')
#
# ~/anaconda/lib/python3.6/site-packages/geopandas/tools/geocoding.py in geocode(strings, provider, **kwargs)
#      60
#      61     """
# ---> 62     return _query(strings, True, provider, **kwargs)
#      63
#      64
#
# ~/anaconda/lib/python3.6/site-packages/geopandas/tools/geocoding.py in _query(data, forward, provider, **kwargs)
#     124         try:
#     125             if forward:
# --> 126                 results[i] = coder.geocode(s)
#     127             else:
#     128                 results[i] = coder.reverse((s.y, s.x), exactly_one=True)
#
# ...
